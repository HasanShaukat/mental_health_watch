# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
depression = pd.read_csv('data/prevalence-of-depression-males-vs-females.csv')
depression.head()
# Out:
#    index       Entity      Code  Year  \
# 0      0     Abkhazia  OWID_ABK  2015
# 1      1  Afghanistan       AFG  1990
# 2      2  Afghanistan       AFG  1991
# 3      3  Afghanistan       AFG  1992
# 4      4  Afghanistan       AFG  1993
#
#    Prevalence - Depressive disorders - Sex: Male - Age: Age-standardized (Percent)  \
# 0                                                NaN
# 1                                           4.291054
# 2                                           4.293268
# 3                                           4.298265
# 4                                           4.303087
#
#    Prevalence - Depressive disorders - Sex: Female - Age: Age-standardized (Percent)  \
# 0                                                NaN
# 1                                           5.859656
# 2                                           5.853078
# 3                                           5.850020
# 4                                           5.844987
#
# ...

# %%
len(depression)
# Out:
# 56395

# %%
len(depression[depression.Entity=='Germany'])
# Out:
# 259

# %%
depression[depression.Entity=='Germany']
# Out:
#        index   Entity Code  Year  \
# 18771  18771  Germany  DEU  1990
# 18772  18772  Germany  DEU  1991
# 18773  18773  Germany  DEU  1992
# 18774  18774  Germany  DEU  1993
# 18775  18775  Germany  DEU  1994
# ...      ...      ...  ...   ...
# 19025  19025  Germany  DEU  1987
# 19026  19026  Germany  DEU  1988
# 19027  19027  Germany  DEU  1989
# 19028  19028  Germany  DEU  2020
# 19029  19029  Germany  DEU  2021
#
#        Prevalence - Depressive disorders - Sex: Male - Age: Age-standardized (Percent)  \
# 18771                                           2.900334
# 18772                                           2.883287
# 18773                                           2.871103
# 18774                                           2.861540
# 18775                                           2.854210
# ...                                                  ...
# 19025                                                NaN
# 19026                                                NaN
# ...

# %%
de_depression = depression[depression.Code=='DEU']
men = 'Prevalence - Depressive disorders - Sex: Male - Age: Age-standardized (Percent)'
women = 'Prevalence - Depressive disorders - Sex: Female - Age: Age-standardized (Percent)'
de_depression.head()
# Out:
#        index   Entity Code  Year  \
# 18771  18771  Germany  DEU  1990
# 18772  18772  Germany  DEU  1991
# 18773  18773  Germany  DEU  1992
# 18774  18774  Germany  DEU  1993
# 18775  18775  Germany  DEU  1994
#
#        Prevalence - Depressive disorders - Sex: Male - Age: Age-standardized (Percent)  \
# 18771                                           2.900334
# 18772                                           2.883287
# 18773                                           2.871103
# 18774                                           2.861540
# 18775                                           2.854210
#
#        Prevalence - Depressive disorders - Sex: Female - Age: Age-standardized (Percent)  \
# 18771                                           3.974717
# 18772                                           3.966109
# 18773                                           3.960032
# 18774                                           3.955140
# 18775                                           3.949021
#
# ...

# %%
subset = depression[depression.Code=='DEU']
#subset = df[df.Entity=='Pakistan']

plt.plot(subset.Year, subset[men], label='men')
plt.plot(subset.Year, subset[women], label='women')
plt.legend()

# %%
subset = depression[depression.Code=='DEU']
plt.plot(subset.Year, subset[men], label='German men')

subset = df[df.Entity=='Pakistan']
plt.plot(subset.Year, subset[men], label='Pakistani men')

plt.legend()

# %%
subset = depression[depression.Code=='DEU']
plt.plot(subset.Year, subset[women], label='German women')

subset = df[df.Entity=='Pakistan']
plt.plot(subset.Year, subset[women], label='Pakistani women')

plt.legend()

# %%
depression.Continent.value_counts()
# Out:
# Continent
# Europe           75
# Asia             62
# Africa           61
# North America    42
# Oceania          26
# South America    15
# Antarctica        4
# Name: count, dtype: int64

# %%
countries = depression[depression.Continent=='Europe'].Entity.unique()

for country in countries:
    subset = depression[depression.Entity==country]
    plt.plot(subset.Year, subset[women], label=f'{country} women')

#plt.legend()

# %%
depression[depression.Code=='DEU']
# Out:
#        index   Entity Code  Year  \
# 18771  18771  Germany  DEU  1990
# 18772  18772  Germany  DEU  1991
# 18773  18773  Germany  DEU  1992
# 18774  18774  Germany  DEU  1993
# 18775  18775  Germany  DEU  1994
# ...      ...      ...  ...   ...
# 19025  19025  Germany  DEU  1987
# 19026  19026  Germany  DEU  1988
# 19027  19027  Germany  DEU  1989
# 19028  19028  Germany  DEU  2020
# 19029  19029  Germany  DEU  2021
#
#        Prevalence - Depressive disorders - Sex: Male - Age: Age-standardized (Percent)  \
# 18771                                           2.900334
# 18772                                           2.883287
# 18773                                           2.871103
# 18774                                           2.861540
# 18775                                           2.854210
# ...                                                  ...
# 19025                                                NaN
# 19026                                                NaN
# ...

# %%
subset
# Out:
#        index         Entity Code  Year  \
# 56394  56394  Åland Islands  ALA  2015
#
#        Prevalence - Depressive disorders - Sex: Male - Age: Age-standardized (Percent)  \
# 56394                                                NaN
#
#        Prevalence - Depressive disorders - Sex: Female - Age: Age-standardized (Percent)  \
# 56394                                                NaN
#
#        Population (historical estimates) Continent
# 56394                                NaN    Europe

# %%
subset = depression[depression.Year==2019]

subset.sort_values(by=women, ascending=True)[['Entity',women]].head(20)
# Out:
#                          Entity  \
# 7349                     Brunei
# 10577                  Colombia
# 33430                   Myanmar
# 44571                 Singapore
# 24678                     Japan
# 46473               South Korea
# 39677                    Poland
# 39158                      Peru
# 26456                      Laos
# 22801                 Indonesia
# 44090                Seychelles
# 2110                  Argentina
# 54757                   Vietnam
# 36798  Northern Mariana Islands
# 49917                     Timor
# 1097             American Samoa
# 47244                 Sri Lanka
# 50507                     Tonga
# 42550                     Samoa
# 25715                  Kiribati
#
#        Prevalence - Depressive disorders - Sex: Female - Age: Age-standardized (Percent)
# 7349                                            2.105262
# 10577                                           2.448199
# 33430                                           2.511807
# ...

# %%
anxeity = pd.read_csv('data/prevalence-of-anxiety-disorders-males-vs-females.csv')
anxeity_men = 'Prevalence - Anxiety disorders - Sex: Male - Age: Age-standardized (Percent)'
anxeity_women = 'Prevalence - Anxiety disorders - Sex: Female - Age: Age-standardized (Percent)'

anxeity.head()
# Out:
#    index       Entity      Code  Year  \
# 0      0     Abkhazia  OWID_ABK  2015
# 1      1  Afghanistan       AFG  1990
# 2      2  Afghanistan       AFG  1991
# 3      3  Afghanistan       AFG  1992
# 4      4  Afghanistan       AFG  1993
#
#    Prevalence - Anxiety disorders - Sex: Male - Age: Age-standardized (Percent)  \
# 0                                                NaN
# 1                                           3.556843
# 2                                           3.548885
# 3                                           3.542779
# 4                                           3.538304
#
#    Prevalence - Anxiety disorders - Sex: Female - Age: Age-standardized (Percent)  \
# 0                                                NaN
# 1                                           5.971172
# 2                                           5.980482
# 3                                           5.988175
# 4                                           5.993858
#
# ...

# %%
subset = anxeity[anxeity.Code=='DEU']
plt.plot(subset.Year, subset[anxeity_women], label='German women')

subset = anxeity[anxeity.Entity=='Pakistan']
plt.plot(subset.Year, subset[anxeity_women], label='Pakistani women')

plt.legend()

# %%
subset = anxeity[anxeity.Code=='DEU']
plt.plot(subset.Year, subset[anxeity_men], label='German men')

subset = anxeity[anxeity.Entity=='Pakistan']
plt.plot(subset.Year, subset[anxeity_men], label='Pakistani men')

plt.legend()

# %%
subset = anxeity[anxeity.Code=='DEU']
plt.plot(subset.Year, subset[anxeity_men], label='Germany Anxeity')

subset = depression[depression.Entity=='Germany']
plt.plot(subset.Year, subset[men], label='Germany Depression')

plt.legend()
plt.title('Anxeity and Depression Comparison (Men)')
# Out:
# Text(0.5, 1.0, 'Anxeity and Depression Comparison (Men)')

# %%
subset = anxeity[anxeity.Code=='DEU']
plt.plot(subset.Year, subset[anxeity_women], label='Germany Anxeity')

subset = depression[depression.Entity=='Germany']
plt.plot(subset.Year, subset[women], label='Germany Depression')

plt.legend()
plt.title('Anxeity and Depression Comparison (Women)')
# Out:
# Text(0.5, 1.0, 'Anxeity and Depression Comparison (Women)')

# %% [markdown]
# ## Save Files

# %%
depression.rename(columns={men:'depression_men', women:'depression_women'}, inplace=True)
depression
# Out:
#        index         Entity      Code  Year  depression_men  depression_women  \
# 0          0       Abkhazia  OWID_ABK  2015             NaN               NaN
# 1          1    Afghanistan       AFG  1990        4.291054          5.859656
# 2          2    Afghanistan       AFG  1991        4.293268          5.853078
# 3          3    Afghanistan       AFG  1992        4.298265          5.850020
# 4          4    Afghanistan       AFG  1993        4.303087          5.844987
# ...      ...            ...       ...   ...             ...               ...
# 56390  56390       Zimbabwe       ZWE  1988             NaN               NaN
# 56391  56391       Zimbabwe       ZWE  1989             NaN               NaN
# 56392  56392       Zimbabwe       ZWE  2020             NaN               NaN
# 56393  56393       Zimbabwe       ZWE  2021             NaN               NaN
# 56394  56394  Åland Islands       ALA  2015             NaN               NaN
#
# ...

# %%
anxeity.rename(columns={anxeity_men:'anxeity_men', anxeity_women:'anxeity_women'}, inplace=True)
anxeity
# Out:
#        index         Entity      Code  Year  anxeity_men  anxeity_women  \
# 0          0       Abkhazia  OWID_ABK  2015          NaN            NaN
# 1          1    Afghanistan       AFG  1990     3.556843       5.971172
# 2          2    Afghanistan       AFG  1991     3.548885       5.980482
# 3          3    Afghanistan       AFG  1992     3.542779       5.988175
# 4          4    Afghanistan       AFG  1993     3.538304       5.993858
# ...      ...            ...       ...   ...          ...            ...
# 56390  56390       Zimbabwe       ZWE  1988          NaN            NaN
# 56391  56391       Zimbabwe       ZWE  1989          NaN            NaN
# 56392  56392       Zimbabwe       ZWE  2020          NaN            NaN
# 56393  56393       Zimbabwe       ZWE  2021          NaN            NaN
# 56394  56394  Åland Islands       ALA  2015          NaN            NaN
#
#        Population (historical estimates) Continent
# 0                                    NaN      Asia
# ...

# %%
df = depression.merge(anxeity, on=['Code','Entity','Year'], how='left')[['Entity','Code','Year','depression_men','depression_women','anxeity_men','anxeity_women']]
df.to_csv('data/depression_and_anxiety_dataset.csv', index=False)
print('File saved successfully!')
# Out:
# File saved successfully!
